# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
stadiums = Path("stadiums.csv")

stadiums_data = pd.read_csv(stadiums)

stadiums_data
# Out:
#              stadium_name  stadium_location  stadium_open  stadium_close  \
# 0        Acrisure Stadium    Pittsburgh, PA        2001.0            NaN
# 1              Alamo Dome   San Antonio, TX           NaN            NaN
# 2       Allegiant Stadium      Paradise, NV        2020.0            NaN
# 3           Allianz Arena   Munich, Germany           NaN            NaN
# 4          Alltel Stadium  Jacksonville, FL           NaN            NaN
# ..                    ...               ...           ...            ...
# 113  War Memorial Stadium       Buffalo, NY        1960.0         1972.0
# 114       Wembley Stadium        London, UK        2007.0            NaN
# 115         Wrigley Field       Chicago, IL        1920.0         1970.0
# 116             Yale Bowl     New Haven, CT           NaN            NaN
# 117        Yankee Stadium         Bronx, NY           NaN            NaN
#
#     stadium_type                              stadium_address  \
# ...

# %%
# Filter the data to only show the required dates
stadiums_data_filtered = stadiums_data[~stadiums_data['stadium_close'].between(1900, 2012)]

stadiums_data_filtered
# Out:
#                       stadium_name  stadium_location  stadium_open  \
# 0                 Acrisure Stadium    Pittsburgh, PA        2001.0
# 1                       Alamo Dome   San Antonio, TX           NaN
# 2                Allegiant Stadium      Paradise, NV        2020.0
# 3                    Allianz Arena   Munich, Germany           NaN
# 4                   Alltel Stadium  Jacksonville, FL           NaN
# ..                             ...               ...           ...
# 109              U.S. Bank Stadium   Minneapolis, MN        2016.0
# 110  University of Phoenix Stadium      Glendale, AZ        2006.0
# 114                Wembley Stadium        London, UK        2007.0
# 116                      Yale Bowl     New Haven, CT           NaN
# 117                 Yankee Stadium         Bronx, NY           NaN
#
#      stadium_close stadium_type                           stadium_address  \
# 0              NaN      outdoor  100 Art Rooney Ave, Pittsburgh, PA 15212
# ...

# %%
valid_stadiums = [
    "Acrisure Stadium",
    "Allegiant Stadium",
    "Arrowhead Stadium",
    "AT&T Stadium",
    "Bank of America Stadium",
    "Caesars Superdome",
    "Cleveland Browns Stadium",
    "Empower Field at Mile High",
    "FedEx Field",
    "Ford Field",
    "Gillette Stadium",
    "Hard Rock Stadium",
    "Highmark Stadium",
    "Lambeau Field",
    "Levi's Stadium",
    "Lincoln Financial Field",
    "Lucas Oil Stadium",
    "Lumen Field",
    "M&T Bank Stadium",
    "Mercedes-Benz Stadium",
    "MetLife Stadium",
    "Nissan Stadium",
    "NRG Stadium",
    "Paycor Stadium",
    "Raymond James Stadium",
    "SoFi Stadium",
    "Soldier Field",
    "State Farm Stadium",
    "TIAA Bank Field",
    "U.S. Bank Stadium"
]

stadiums_data_filtered = stadiums_data_filtered[stadiums_data_filtered['stadium_name'].isin(valid_stadiums)]

stadiums_data_filtered
# Out:
#                    stadium_name     stadium_location  stadium_open  \
# 0              Acrisure Stadium       Pittsburgh, PA        2001.0
# 2             Allegiant Stadium         Paradise, NV        2020.0
# 7             Arrowhead Stadium      Kansas City, MO        1972.0
# 8                  AT&T Stadium        Arlington, TX        2009.0
# 11      Bank of America Stadium        Charlotte, NC        1996.0
# 14            Caesars Superdome      New Orleans, LA        1975.0
# 23   Empower Field at Mile High           Denver, CO        2001.0
# 26                  FedEx Field         Landover, MD        1997.0
# 29                   Ford Field          Detroit, MI        2002.0
# 35             Gillette Stadium       Foxborough, MA        2002.0
# 36            Hard Rock Stadium    Miami Gardens, FL        1987.0
# 39             Highmark Stadium     Orchard Park, NY        1973.0
# 48                Lambeau Field        Green Bay, WI        1957.0
# ...

# %%
# Export the score_data_filtered into a csv
stadiums_data_filtered.to_csv("output_data/stadiums.csv")
