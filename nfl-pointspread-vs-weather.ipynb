# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import csv

nfl_data_path = "output_data/nfl.csv"

nfl_data = pd.read_csv(nfl_data_path, encoding="latin1")
nfl_data
# Out:
#       Unnamed: 0 schedule_date  schedule_season schedule_week  \
# 0          10809      9/5/2013             2013             1
# 1          10810      9/8/2013             2013             1
# 2          10811      9/8/2013             2013             1
# 3          10812      9/8/2013             2013             1
# 4          10813      9/8/2013             2013             1
# ...          ...           ...              ...           ...
# 2692       13511     1/22/2023             2022      Division
# 2693       13512     1/22/2023             2022      Division
# 2694       13513     1/29/2023             2022    Conference
# 2695       13514     1/29/2023             2022    Conference
# 2696       13515     2/12/2023             2022     Superbowl
#
#       schedule_playoff team_home  score_home  score_away  \
# 0                False       DEN          49          27
# 1                False       BUF          21          23
# 2                False       CAR           7          12
# 3                False       CHI          24          21
# 4                False       CLE          10          23
# ...                ...       ...         ...         ...
# 2692              True       BUF          10          27
# 2693              True        SF          19          12
# 2694              True        KC          23          20
# 2695              True       PHI          31           7
# 2696              True       PHI          35          38
#
#       raw_score_difference (home-away) team_away  ...  \
# 0                                   22       BAL  ...
# 1                                   -2        NE  ...
# 2                                   -5       SEA  ...
# 3                                    3       CIN  ...
# 4                                  -13       MIA  ...
# ...                                ...       ...  ...
# 2692                               -17       CIN  ...
# 2693                                 7       DAL  ...
# 2694                                 3       CIN  ...
# 2695                                24        SF  ...
# 2696                                -3        KC  ...
#
#      favourite_score_difference spread_favorite  win_loss  over_under_line  \
# 0                           -22            -7.5      True             49.5
# 1                            -2           -10.5     False             51.5
# 2                            -5            -3.5      True             45.0
# 3                            -3            -3.0     False             42.0
# 4                            13            -2.5     False             40.5
# ...                         ...             ...       ...              ...
# 2692                         17            -6.0     False             48.5
# 2693                         -7            -3.5      True             46.5
# 2694                         -3            -1.5      True             48.0
# 2695                        -24            -2.5      True             45.5
# 2696                          3            -1.0     False             51.0
#
#                                   stadium  stadium_neutral  \
# 0     Sports Authority Field at Mile High            False
# 1                    Ralph Wilson Stadium            False
# 2                 Bank of America Stadium            False
# 3                           Soldier Field            False
# 4                     FirstEnergy Stadium            False
# ...                                   ...              ...
# 2692                     Highmark Stadium            False
# 2693                       Levi's Stadium            False
# 2694      GEHA Field at Arrowhead Stadium            False
# 2695              Lincoln Financial Field            False
# 2696                   State Farm Stadium             True
#
#      weather_temperature  weather_wind_mph  weather_humidity  \
# 0                   83.0               7.0              30.0
# 1                   65.0               6.0              55.0
# 2                   87.0               7.0              48.0
# 3                   77.0              13.0              79.0
# 4                   72.0              16.0              80.0
# ...                  ...               ...               ...
# 2692                32.0               4.0             100.0
# 2693                55.0              19.0              47.0
# 2694                22.0              13.0              55.0
# 2695                52.0              14.0              48.0
# 2696                76.0               8.0               8.0
#
#                weather_detail
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 2692                     snow
# 2693                      NaN
# 2694                      NaN
# 2695                     rain
# 2696  retractable (open roof)
#
# [2697 rows x 22 columns]

# %%
# Separate columns needed
nfl_data = nfl_data[["schedule_season","team_home", "score_home", "score_away", "raw_score_difference (home-away)", "team_away", "team_favorite_id", "favourite_direction", "favourite_score_difference", "spread_favorite", "win_loss","weather_temperature", "weather_wind_mph"]].copy()

# Rename multiple columns
nfl_data_clean = nfl_data.rename(columns={'schedule_season': 'Season', 'team_home': 'Home Team', 'score_home': 'Home Team Score','score_away': 'Away Team Score', 'raw_score_difference (home-away)': 'Score Difference', 'team_away': 'Away Team ID', 'team_favorite_id': 'Team Favourite ID', 
                                          'favourite_direction': 'Home/Away Direction', 'favourite_score_difference':'Home/Away Direction Diff','spread_favorite':'Spread Favourite', 'win_loss':'Win/Loss','weather_temperature' : 'Temperature (°F)', 'weather_wind_mph' : 'Wind (MPH)'})

nfl_data_clean
# Out:
#       Season Home Team  Home Team Score  Away Team Score  Score Difference  \
# 0       2013       DEN               49               27                22
# 1       2013       BUF               21               23                -2
# 2       2013       CAR                7               12                -5
# 3       2013       CHI               24               21                 3
# 4       2013       CLE               10               23               -13
# ...      ...       ...              ...              ...               ...
# 2692    2022       BUF               10               27               -17
# 2693    2022        SF               19               12                 7
# 2694    2022        KC               23               20                 3
# 2695    2022       PHI               31                7                24
# 2696    2022       PHI               35               38                -3
#
#      Away Team ID Team Favourite ID Home/Away Direction  \
# 0             BAL               DEN                Home
# 1              NE                NE                Away
# 2             SEA               SEA                Away
# 3             CIN               CHI                Home
# 4             MIA               CLE                Home
# ...           ...               ...                 ...
# 2692          CIN               BUF                Home
# 2693          DAL                SF                Home
# 2694          CIN                KC                Home
# 2695           SF               PHI                Home
# 2696           KC               PHI                Home
#
#       Home/Away Direction Diff  Spread Favourite  Win/Loss  Temperature (°F)  \
# 0                          -22              -7.5      True              83.0
# 1                           -2             -10.5     False              65.0
# 2                           -5              -3.5      True              87.0
# 3                           -3              -3.0     False              77.0
# 4                           13              -2.5     False              72.0
# ...                        ...               ...       ...               ...
# 2692                        17              -6.0     False              32.0
# 2693                        -7              -3.5      True              55.0
# 2694                        -3              -1.5      True              22.0
# 2695                       -24              -2.5      True              52.0
# 2696                         3              -1.0     False              76.0
#
#       Wind (MPH)
# 0            7.0
# 1            6.0
# 2            7.0
# 3           13.0
# 4           16.0
# ...          ...
# 2692         4.0
# 2693        19.0
# 2694        13.0
# 2695        14.0
# 2696         8.0
#
# [2697 rows x 13 columns]

# %%
# Determine whether it was a win or loss for the Spread Favourite
nfl_data_clean["Win/Loss"] = nfl_data_clean["Win/Loss"].apply(lambda x: 'Win' if x==True else 'Loss')
nfl_data_clean
# Out:
#       Season Home Team  Home Team Score  Away Team Score  Score Difference  \
# 0       2013       DEN               49               27                22
# 1       2013       BUF               21               23                -2
# 2       2013       CAR                7               12                -5
# 3       2013       CHI               24               21                 3
# 4       2013       CLE               10               23               -13
# ...      ...       ...              ...              ...               ...
# 2692    2022       BUF               10               27               -17
# 2693    2022        SF               19               12                 7
# 2694    2022        KC               23               20                 3
# 2695    2022       PHI               31                7                24
# 2696    2022       PHI               35               38                -3
#
#      Away Team ID Team Favourite ID Home/Away Direction  \
# 0             BAL               DEN                Home
# 1              NE                NE                Away
# 2             SEA               SEA                Away
# 3             CIN               CHI                Home
# 4             MIA               CLE                Home
# ...           ...               ...                 ...
# 2692          CIN               BUF                Home
# 2693          DAL                SF                Home
# 2694          CIN                KC                Home
# 2695           SF               PHI                Home
# 2696           KC               PHI                Home
#
#       Home/Away Direction Diff  Spread Favourite Win/Loss  Temperature (°F)  \
# 0                          -22              -7.5      Win              83.0
# 1                           -2             -10.5     Loss              65.0
# 2                           -5              -3.5      Win              87.0
# 3                           -3              -3.0     Loss              77.0
# 4                           13              -2.5     Loss              72.0
# ...                        ...               ...      ...               ...
# 2692                        17              -6.0     Loss              32.0
# 2693                        -7              -3.5      Win              55.0
# 2694                        -3              -1.5      Win              22.0
# 2695                       -24              -2.5      Win              52.0
# 2696                         3              -1.0     Loss              76.0
#
#       Wind (MPH)
# 0            7.0
# 1            6.0
# 2            7.0
# 3           13.0
# 4           16.0
# ...          ...
# 2692         4.0
# 2693        19.0
# 2694        13.0
# 2695        14.0
# 2696         8.0
#
# [2697 rows x 13 columns]

# %%
# Separate columns needed
nfl_data_clean1 = nfl_data_clean[["Season","Win/Loss","Temperature (°F)", "Wind (MPH)"]].copy()
nfl_data_clean1
# Out:
#       Season Win/Loss  Temperature (°F)  Wind (MPH)
# 0       2013      Win              83.0         7.0
# 1       2013     Loss              65.0         6.0
# 2       2013      Win              87.0         7.0
# 3       2013     Loss              77.0        13.0
# 4       2013     Loss              72.0        16.0
# ...      ...      ...               ...         ...
# 2692    2022     Loss              32.0         4.0
# 2693    2022      Win              55.0        19.0
# 2694    2022      Win              22.0        13.0
# 2695    2022      Win              52.0        14.0
# 2696    2022     Loss              76.0         8.0
#
# [2697 rows x 4 columns]

# %%
# Calculate how many games were a Win or a Loss for each NFL Season
win_loss_weather_count = nfl_data_clean1.groupby(["Season", "Win/Loss", "Temperature (°F)", "Wind (MPH)"]).count()
win_loss_weather_count
# Out:
# Empty DataFrame
# Columns: []
# Index: [(2013, Loss, 9.0, 9.0), (2013, Loss, 20.0, 10.0), (2013, Loss, 23.0, 5.0), (2013, Loss, 23.0, 22.0), (2013, Loss, 25.0, 8.0), (2013, Loss, 25.0, 12.0), (2013, Loss, 26.0, 7.0), (2013, Loss, 26.0, 9.0), (2013, Loss, 27.0, 20.0), (2013, Loss, 28.0, 4.0), (2013, Loss, 31.0, 5.0), (2013, Loss, 33.0, 7.0), (2013, Loss, 33.0, 31.0), (2013, Loss, 37.0, 2.0), (2013, Loss, 37.0, 5.0), (2013, Loss, 39.0, 6.0), (2013, Loss, 41.0, 8.0), (2013, Loss, 43.0, 3.0), (2013, Loss, 44.0, 5.0), (2013, Loss, 44.0, 8.0), (2013, Loss, 45.0, 5.0), (2013, Loss, 46.0, 9.0), (2013, Loss, 47.0, 5.0), (2013, Loss, 49.0, 5.0), (2013, Loss, 49.0, 6.0), (2013, Loss, 50.0, 6.0), (2013, Loss, 50.0, 9.0), (2013, Loss, 52.0, 4.0), (2013,

# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/n_/kb7vpnwj0d9gyxnm53rhyjv00000gn/T/ipykernel_22481/570983566.py in <module>
#       1 # Analysis to see if Temperature (°F) affects Win/Loss
#       2 # Summary statistics table for weather metrics of Favourite Spread
# ----> 3 weather_agg = win_loss_count.groupby(["Win/Loss"])[["Temperature (°F)", "Wind (MPH)"]].agg(["mean", "median", "var", "std", "sem"], skipna=False)
#       4 weather_agg
#       5
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1336                 stacklevel=find_stack_level(),
#    1337             )
# -> 1338         return super().__getitem__(key)
#    1339
#    1340     def _gotitem(self, key, ndim: int, subset=None):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/base.py in __getitem__(self, key)
#     238             if len(self.obj.columns.intersection(key)) != len(set(key)):
#     239                 bad_keys = list(set(key).difference(self.obj.columns))
# --> 240                 raise KeyError(f"Columns not found: {str(bad_keys)[1:-1]}")
#     241             return self._gotitem(list(key), ndim=2)
#     242
#
# KeyError: "Columns not found: 'Wind (MPH)', 'Temperature (°F)'"

# %%
# Import seaborn
import seaborn as sns

# Create a Bar Chart
plt.figure(figsize=(10.5,5))
sns.set_palette("Set1")
ax = sns.barplot(data= win_loss_count, x= "Season", y= "Spread Favourite", hue="Win/Loss")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.savefig("winlossbar.png")

# %%
win_loss_team = nfl_data_clean.groupby(["Home Team", "Win/Loss"]).count()
win_loss_team = nfl_data_clean.groupby(["Home Team", "Win/Loss"]).count()["Spread Favourite"].reset_index()
win_loss_team

# %%
# Import seaborn
import seaborn as sns

# Create a Bar Chart
plt.figure(figsize=(14,5))

plt.xticks(rotation=75)

sns.set_palette("Set3")

sns.barplot(data= win_loss_team, x="Home Team", y="Spread Favourite", hue="Win/Loss")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.savefig("hometeam.png")

# %%
# Track the max and min values
max_value = float('-inf')
min_value = float('inf')

# Iterate over the values in the column
for value in win_loss_team['Spread Favourite']:
    if value > max_value:
        max_value = value
    if value < min_value:
        min_value = value

# Print the max and min values
print("Maximum value:", max_value)
print("Minimum value:", min_value)

# %%
max_team = win_loss_team.groupby(["Home Team"]).max()["Spread Favourite"]
max_team

# %%
min_team = win_loss_team.groupby(["Home Team"]).min()["Spread Favourite"]
min_team

# %%
win_loss_team = nfl_data_clean.groupby(["Away Team ID", "Win/Loss"]).count()
win_loss_team = nfl_data_clean.groupby(["Away Team ID", "Win/Loss"]).count()["Spread Favourite"].reset_index()
win_loss_team

# %%
# Import seaborn
import seaborn as sns

# Create a Bar Chart
plt.figure(figsize=(15,5))

plt.xticks(rotation=75)
sns.set_palette("Set1")

sns.barplot(data= win_loss_team, x="Away Team ID", y="Spread Favourite", hue="Win/Loss")
sns.move_legend(ax, "upper right", bbox_to_anchor=(1, 1))
plt.savefig("awayteam.png")

# %%
# Track the max and min values
max_value = float('-inf')
min_value = float('inf')

# Iterate over the values in the column
for value in win_loss_team['Spread Favourite']:
    if value > max_value:
        max_value = value
    if value < min_value:
        min_value = value

# Print the max and min values
print("Maximum value:", max_value)
print("Minimum value:", min_value)

# %%
max_team = win_loss_team.groupby(["Away Team ID"]).max()["Spread Favourite"]
max_team

# %%
min_team = win_loss_team.groupby(["Away Team ID"]).min()["Spread Favourite"]
min_team

# %%
nfl_data.describe()

# %%
nfl_data.head()

# %%
nfl_data.tail()

# %%
nfl_data.dropna (inplace=True)
nfl_data
