# %%
# setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import requests
import time
from scipy.stats import linregress
import csv

# csv files
#stadiums_data_path = "Betting_Analytics_Project\output_data/nfl_stadiums.csv"
teams_data_path = "output_data/teams.csv"
scores_data_path = "output_data/scores.csv"
stadiums_data_path = "output_data/stadiums.csv"

# read data
#stadiums_data = pd.read_csv(stadiums_data_path) 
teams_data = pd.read_csv(teams_data_path)
scores_data = pd.read_csv(scores_data_path)
stadiums_data = pd.read_csv(stadiums_data_path)

# %%
# display data test
teams_data.head()
# Out:
#            team_name team_name_short team_id team_id_pfr team_conference  \
# 0  Arizona Cardinals       Cardinals     ARI         CRD             NFC
# 1    Atlanta Falcons         Falcons     ATL         ATL             NFC
# 2    Baltimore Colts           Colts     IND         CLT             AFC
# 3   Baltimore Ravens          Ravens     BAL         RAV             AFC
# 4    Boston Patriots        Patriots      NE         NWE             AFC
#
#   team_division team_conference_pre2002 team_division_pre2002
# 0      NFC West                     NFC              NFC West
# 1     NFC South                     NFC              NFC West
# 2           NaN                     AFC              AFC East
# 3     AFC North                     AFC           AFC Central
# 4           NaN                     AFC                   NaN

# %%
teams_data.dropna()
teams_data
# Out:
#                    team_name team_name_short team_id team_id_pfr  \
# 0          Arizona Cardinals       Cardinals     ARI         CRD
# 1            Atlanta Falcons         Falcons     ATL         ATL
# 2            Baltimore Colts           Colts     IND         CLT
# 3           Baltimore Ravens          Ravens     BAL         RAV
# 4            Boston Patriots        Patriots      NE         NWE
# 5              Buffalo Bills           Bills     BUF         BUF
# 6          Carolina Panthers        Panthers     CAR         CAR
# 7              Chicago Bears           Bears     CHI         CHI
# 8         Cincinnati Bengals         Bengals     CIN         CIN
# 9           Cleveland Browns          Browns     CLE         CLE
# 10            Dallas Cowboys         Cowboys     DAL         DAL
# 11            Denver Broncos         Broncos     DEN         DEN
# 12             Detroit Lions           Lions     DET         DET
# ...

# %%
scores_data.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0      9/2/1966             1966             1             False
# 1      9/3/1966             1966             1             False
# 2      9/4/1966             1966             1             False
# 3      9/9/1966             1966             2             False
# 4     9/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins          14          23  Oakland Raiders
# 1      Houston Oilers          45           7   Denver Broncos
# 2  San Diego Chargers          27           7    Buffalo Bills
# 3      Miami Dolphins          14          19    New York Jets
# 4   Green Bay Packers          24           3  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# ...

# %%
scores_data = scores_data.dropna()
scores_data
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 538       1/12/1969             1968     Superbowl              True
# 727       1/11/1970             1969     Superbowl              True
# 2500      1/21/1979             1978     Superbowl              True
# 9774      9/27/2009             2009             3             False
# 9780      9/27/2009             2009             3             False
# ...             ...              ...           ...               ...
# 11059    12/29/2013             2013            17             False
# 11061    12/29/2013             2013            17             False
# 13511     1/22/2023             2022      Division              True
# 13514     1/29/2023             2022    Conference              True
# 13515     2/12/2023             2022     Superbowl              True
#
#                   team_home  score_home  score_away            team_away  \
# ...

# %%
stadiums_data
# Out:
#                             stadium_name     stadium_location  stadium_open  \
# 0                       Acrisure Stadium       Pittsburgh, PA        2001.0
# 1                             Alamo Dome      San Antonio, TX           NaN
# 2                      Allegiant Stadium         Paradise, NV        2020.0
# 3                          Allianz Arena      Munich, Germany           NaN
# 4                         Alltel Stadium     Jacksonville, FL           NaN
# 5                         Alumni Stadium    Chestnut Hill, MA           NaN
# 6                        Anaheim Stadium          Anaheim, CA        1980.0
# 7                      Arrowhead Stadium      Kansas City, MO        1972.0
# 8                           AT&T Stadium        Arlington, TX        2009.0
# 9          Atlanta-Fulton County Stadium          Atlanta, GA        1966.0
# 10                        Balboa Stadium        San Diego, CA           NaN
# ...
